# %%
# !pip uninstall timm mambavision -y
# Out:
# /opt/conda/lib/python3.10/pty.py:89: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   pid, fd = os.forkpty()
# Found existing installation: timm 1.0.7
# Uninstalling timm-1.0.7:
#   Successfully uninstalled timm-1.0.7
# WARNING: Skipping mambavision as it is not installed.

# %%
# !pip install timm==0.9.0 mambavision==1.0.9 einops
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 68.5/68.5 kB 704.5 kB/s eta 0:00:00a 0:00:01
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 446.5/446.5 kB 4.1 MB/s eta 0:00:0000:0100:01
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.9/42.9 kB 2.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 21.4 MB/s eta 0:00:00a 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.9/56.9 kB 4.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.2/43.2 kB 3.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 209.4/209.4 MB 7.7 MB/s eta 0:00:00:00:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.2/3.2 MB 76.8 MB/s eta 0:00:00:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 74.6/74.6 kB 5.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 247.8/247.8 kB 18.9 MB/s eta 0:00:00
# ...

# %%
from transformers import AutoModelForImageClassification
from PIL import Image
from timm.data.transforms_factory import create_transform
import requests

# Load the MambaVision model pretrained on ImageNet-1K dataset.
model = AutoModelForImageClassification.from_pretrained("nvidia/MambaVision-T-1K", trust_remote_code=True)

# Print the model's configuration to verify its loading.
print(model.config)
# Out:
# config.json:   0%|          | 0.00/36.4k [00:00<?, ?B/s]
# configuration_mambavision.py:   0%|          | 0.00/625 [00:00<?, ?B/s]
# A new version of the following files was downloaded from https://huggingface.co/nvidia/MambaVision-T-1K:
# - configuration_mambavision.py
# . Make sure to double-check they do not contain any added malicious code. To avoid downloading new versions of the code file, you can pin a revision.
# modeling_mambavision.py:   0%|          | 0.00/27.9k [00:00<?, ?B/s]
# A new version of the following files was downloaded from https://huggingface.co/nvidia/MambaVision-T-1K:
# - modeling_mambavision.py
# . Make sure to double-check they do not contain any added malicious code. To avoid downloading new versions of the code file, you can pin a revision.
# model.safetensors:   0%|          | 0.00/127M [00:00<?, ?B/s]
# MambaVisionConfig {
#   "_name_or_path": "nvidia/MambaVision-T-1K",
#   "architectures": [
#     "MambaVisionModelForImageClassification"
#   ],
# ...

# %% [markdown]
# # summery

# %%
import tensorflow as tf
import tensorflow_hub as hub

# Replace with the actual model URL or path
model_path = "https://tfhub.dev/path/to/your/model"  # Example URL

# Load the model
model = hub.load(model_path)

# Print model summary
model.summary()
# Out:
# ---------------------------------------------------------------------------
# ReadError                                 Traceback (most recent call last)
# File /opt/conda/lib/python3.10/site-packages/tensorflow_hub/resolver.py:192, in DownloadManager.download_and_uncompress(self, fileobj, dst_path)
#     191 try:
# --> 192   file_utils.extract_tarfile_to_destination(
#     193       fileobj, dst_path, log_function=self._log_progress)
#     194   total_size_str = tf_utils.bytes_to_readable_str(
#     195       self._total_bytes_downloaded, True)
#
# File /opt/conda/lib/python3.10/site-packages/tensorflow_hub/file_utils.py:47, in extract_tarfile_to_destination(fileobj, dst_path, log_function)
#      46 """Extract a tarfile. Optional: log the progress."""
# ---> 47 with tarfile.open(mode="r|*", fileobj=fileobj) as tgz:
#      48   for tarinfo in tgz:
#
# File /opt/conda/lib/python3.10/tarfile.py:1836, in TarFile.open(cls, name, mode, fileobj, bufsize, **kwargs)
#    1835 try:
# ...
